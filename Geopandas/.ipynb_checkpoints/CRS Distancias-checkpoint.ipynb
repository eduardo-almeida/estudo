# %%
# Import necessary modules
import geopandas as gpd
from pyproj import CRS
from shapely.geometry import Point
import matplotlib.pyplot as plt

# %%
# Input file that we created on the previous page
fp = "data/Europe_borders_epsg3035.shp"

# Save to disk
data = gpd.read_file(fp)

# %%
data.head()
# Out:
#             TZID                                           geometry
# 0  Europe/Berlin  POLYGON ((4221214.558 3496203.404, 4220681.651...
# 1  Europe/Berlin  POLYGON ((4224860.478 2732279.320, 4224932.819...
# 2  Europe/Berlin  POLYGON ((4104652.176 3390034.953, 4104460.401...
# 3  Europe/Berlin  POLYGON ((4113025.664 3391895.756, 4112879.943...
# 4  Europe/Berlin  POLYGON ((4115871.228 3395282.099, 4114921.348...

# %%
# Create the point representing Helsinki (in WGS84)
hki_lon = 24.9417
hki_lat = 60.1666

# Create GeoDataFrame
crs = CRS("epsg:4326")
helsinki = gpd.GeoDataFrame([[Point(hki_lon, hki_lat)]], geometry='geometry', crs=crs, columns=['geometry'])
#helsinki = gpd.GeoDataFrame([[Point(hki_lon, hki_lat)]], geometry='geometry', crs={'init': 'epsg:4326'}, columns=['geometry'])

# Print
print(helsinki)
# Out:
#                     geometry
# 0  POINT (24.94170 60.16660)

# %%
# Define the projection using the coordinates of our Helsinki point (hki_lat, hki_lon) as the center point
# The .srs here returns the text presentation of the projection
aeqd = CRS(proj='aeqd', ellps='WGS84', datum='WGS84', lat_0=hki_lat, lon_0=hki_lon).srs

# Reproject to aeqd projection using Proj4-string
helsinki = helsinki.to_crs(crs=aeqd)

# Print the data
print(helsinki)

# Print the crs
print('\nCRS:\n', helsinki.crs)
# Out:
#                   geometry
# 0  POINT (0.00000 0.00000)
#
# CRS:
#  +proj=aeqd +ellps=WGS84 +datum=WGS84 +lat_0=60.1666 +lon_0=24.9417 +type=crs

# %%
# Create a copy
europe_borders_aeqd = data.copy()

# %%
# Reproject to aeqd projection that we defined earlier
europe_borders_aeqd = europe_borders_aeqd.to_crs(crs=aeqd)

# Print
print(europe_borders_aeqd.head(2))
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-24-22049ee0b2fb> in <module>
#       1 # Reproject to aeqd projection that we defined earlier
# ----> 2 europe_borders_aeqd = europe_borders_aeqd.to_crs(crs=aeqd)
#       3
#       4 # Print
#       5 print(europe_borders_aeqd.head(2))
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in to_crs(self, crs, epsg, inplace)
#     532         else:
#     533             df = self.copy()
# --> 534         geom = df.geometry.to_crs(crs=crs, epsg=epsg)
#     535         df.geometry = geom
#     536         df.crs = geom.crs
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geoseries.py in to_crs(self, crs, epsg)
#     408         # skip transformation if the input CRS and output CRS are the exact same
#     409         if _PYPROJ_VERSION >= LooseVersion("2.1.2") and pyproj.CRS.from_user_input(
# --> 410             self.crs
#     411         ).is_exact_same(pyproj.CRS.from_user_input(crs)):
#     412             return self
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\crs\crs.py in from_user_input(value)
#     435         if isinstance(value, CRS):
#     436             return value
# --> 437         return CRS(value)
#     438
#     439     def get_geod(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pyproj\crs\crs.py in __init__(self, projparams, **kwargs)
#     291             raise CRSError("Invalid CRS input: {!r}".format(projparams))
#     292
# --> 293         super().__init__(projstring)
#     294
#     295     @staticmethod
#
# pyproj\_crs.pyx in pyproj._crs._CRS.__init__()
#
# CRSError: Invalid projection: {}: (Internal Proj Error: proj_create: Missing "type" key)

# %%
# %matplotlib inline
fig, ax = plt.subplots(figsize=(10,10))

# Plot the country borders
europe_borders_aeqd.plot(ax=ax)

# Plot the Helsinki point on top of the borders using the same axis
helsinki.plot(ax=ax, color='black', markersize=100)
print(helsinki)
# Out:
#                   geometry
# 0  POINT (0.00000 0.00000)
