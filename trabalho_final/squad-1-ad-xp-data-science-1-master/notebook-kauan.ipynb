# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
import numpy as np


figsize(30, 8)

sns.set()

# %%
market = pd.read_csv('estaticos_market.csv', index_col=0)
port1 = pd.read_csv('estaticos_portfolio1.csv', index_col=0)
port2 = pd.read_csv('estaticos_portfolio2.csv', index_col=0)
port3 = pd.read_csv('estaticos_portfolio3.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-ca00d91d9281> in <module>
#       3 port2 = pd.read_csv('estaticos_portfolio2.csv', index_col=0)
#       4 port3 = pd.read_csv('estaticos_portfolio3.csv', index_col=0)
# ----> 5 all_port = pd.merge([market, port1, port2, port3], left_on='id')
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
for id in port2.id:
    print
# Out:
# pandas.core.series.Series

# %%
bla = np.percentile(all_port.idade_empresa_anos, 95)
# (market.loc[market.idade_empresa_anos > bla].id.count()) / market.id.count() * 100 market
bla
# Out:
# /home/kauan/.virtualenvs/codenation/lib/python3.6/site-packages/numpy/lib/function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# nan

# %%
port1.loc[port1.idade_empresa_anos > 30].id.count()
# Out:
# 29

# %%
sns.boxplot(market.idade_empresa_anos)
plt.show()

# %%
sns.boxplot(port1.idade_empresa_anos)
plt.show()

# %%
sns.distplot(market.idade_empresa_anos)
plt.show()

# %%
market.shape
# Out:
# (462298, 181)

# %%
market.idade_empresa_anos.describe()
# Out:
# count    462298.000000
# mean          9.948677
# std           9.615664
# min           0.016438
# 25%           2.756164
# 50%           6.704110
# 75%          14.465753
# max         106.432877
# Name: idade_empresa_anos, dtype: float64

# %%
market.groupby('idade_empresa_anos').id.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-eae9a5a0a1dd> in <module>
# ----> 1 market.groupby('idade_empresa_anos' < 50).id.count()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
market.setor.isna().sum()
# Out:
# 1927

# %%
market.head()
# Out:
#                                                   id  fl_matriz  \
# 0  a6984c3ae395090e3bee8ad63c3758b110de096d5d8195...       True
# 1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...       True
# 2  4a7e5069a397f12fdd7fd57111d6dc5d3ba558958efc02...       True
# 3  3348900fe63216a439d2e5238c79ddd46ede454df7b9d8...       True
# 4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...       True
#
#             de_natureza_juridica sg_uf natureza_juridica_macro  \
# 0  SOCIEDADE EMPRESARIA LIMITADA    RN  ENTIDADES EMPRESARIAIS
# 1          EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 2          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 3          EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 4          EMPRESARIO INDIVIDUAL    RN                  OUTROS
#
#                                           de_ramo             setor  \
# 0                         INDUSTRIA DA CONSTRUCAO  CONSTRUÇÃO CIVIL
# ...

# %%
teste = market.loc[market.idade_emp_cat=='1 a 5']
teste.head()
# Out:
#     Unnamed: 0                                                 id  fl_matriz  \
# 1            1  6178f41ade1365e44bc2c46654c2c8c0eaae27dcb476c4...       True
# 4            4  1f9bcabc9d3173c1fe769899e4fac14b053037b953a1e4...       True
# 13          13  1e954ad5e6a5b7af8582da953709cd702a2f5e5d674361...       True
# 14          14  b0ab88c6ae5e0846f0b8bd63b8472e9ecb73edf9188ff1...       True
# 17          17  82aa41448d40afef92908fdfaa7070b2eedb2ffacb1016...       True
#
#      de_natureza_juridica sg_uf natureza_juridica_macro  \
# 1   EMPRESARIO INDIVIDUAL    PI                  OUTROS
# 4   EMPRESARIO INDIVIDUAL    RN                  OUTROS
# 13  EMPRESARIO INDIVIDUAL    AM                  OUTROS
# 14  EMPRESARIO INDIVIDUAL    RN                  OUTROS
# 17  EMPRESARIO INDIVIDUAL    RO                  OUTROS
#
#                                            de_ramo             setor  \
# 1               SERVICOS DE ALOJAMENTO/ALIMENTACAO           SERVIÇO
# ...

# %%
teste.loc[teste.idade_empresa_anos > 5]
# Out:
# Empty DataFrame
# ...
