# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# %%
df_admin = gpd.read_file('admin.geojson')

# %%
df_admin.head()
# Out:
#     id    osm_id         name            type  admin_leve  \
# 0  1.0 -157452.0      Reghaïa  administrative         8.0
# 1  2.0 -157456.0     Harraoua  administrative         8.0
# 2  3.0 -157175.0   Belouizdad  administrative         8.0
# 3  4.0 -157086.0  Hussein Dey  administrative         8.0
# 4  5.0 -157185.0  Bab El Oued  administrative         8.0
#
#                                             geometry
# 0  POLYGON ((3.31184 36.72522, 3.31947 36.72587, ...
# 1  POLYGON ((3.28718 36.75628, 3.28729 36.75809, ...
# 2  POLYGON ((3.05714 36.75117, 3.05720 36.75127, ...
# 3  POLYGON ((3.08401 36.74357, 3.08408 36.74364, ...
# 4  POLYGON ((3.04410 36.79543, 3.04431 36.79553, ...

# %%
ax = df_admin.plot(color='blue')

# %%
teste = df_admin[0:][5:6].copy()

# %%
teste.plot();

# %%
def escrever_json(lista):
    with open('meu_arquivo.json', 'w') as f:
        json.dump(lista, f)

# %%
teste = teste.to_json()
escrever_json(teste)
